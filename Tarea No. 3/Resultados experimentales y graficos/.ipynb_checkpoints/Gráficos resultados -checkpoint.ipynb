# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Evaluación experimental de inserciones

# %% [markdown]
# ## Con clave User_ID

# %%
# Datos
size_id = [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
arbol_id = [200.4, 400.8, 701.4, 1202.3, 2502.9, 4703.6, 9404.6, 19956.7, 49598.6]
hashCerrado_id = [0, 0, 99.8, 399.6, 899.6, 1799.6, 5799.7, 12698.4, 28487.6]
hashAbierto_id = [0, 98.9, 397.9, 796.9, 1396, 2395.3, 4395.6, 9498.5, 21978.5]
unordered_set_id = [0, 97.4, 294.6, 592, 1189.3, 2286.4, 4683, 9281.7, 20973]
set_id = [100.1, 200.2, 400.1, 799.8, 1699.5, 3699.7, 7898.9, 16497.5, 36188.2]

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de elementos insertados', fontsize='15')
ax1.set_ylabel('Microsegundos', fontsize='15')
ax1.plot(size_id, arbol_id, marker="o", color= "c", label='Arbol_id')
ax1.plot(size_id, hashCerrado_id, marker="*", color= "y", label='HashCerrado_id')
ax1.plot(size_id, hashAbierto_id, marker="^", color= "tab:purple", label='HashAbierto_id')
ax1.plot(size_id, unordered_set_id, marker="s", color= "tab:orange", label='Unordered_set_id')
ax1.plot(size_id, set_id, marker="P", color='tab:blue', label='Set_id')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper left', shadow=True, fontsize='10')
legend.get_frame().set_facecolor('white')

plt.savefig("Grafico de inserciones user_id.png")
plt.show()

# %% [markdown]
# ## Con clave User_Name

# %%
# Datos
size_name_es = [100, 200, 400, 800, 1600, 3200]
size_name = [100, 200, 400, 800, 1600, 3200, 6400, 12800, 25600]
arbol_name = [0, 0, 500, 2700, 9500.9, 39101.8] ## ,206320, 1049930000, 80351000000
hashCerrado_name = [99.7, 199.4, 299.1, 598.9, 1699.1, 3399.7, 8699.4, 17399.8, 34998.3]
hashAbierto_name = [6.05671e-316, 6.05671e-316, 6.05671e-316, 100, 399.7, 1499.6, 4498.7, 10097, 22577.1]
unordered_set_name = [1098.1, 1198.1, 1298.1, 1498.2, 1898.4, 2698.7, 5100.2, 10204.1, 20797.2]
set_name = [5.26354e-316, 100.3, 200.6, 300.9, 601.1, 1101.2, 2101.1, 4604.1, 13797.2]

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de elementos insertados', fontsize='15')
ax1.set_ylabel('Microsegundos', fontsize='15')
ax1.plot(size_name_es, arbol_name, marker="o", color= "c", label='Arbol_name')
ax1.plot(size, hashCerrado_name, marker="*", color= "y", label='HashCerrado_name')
ax1.plot(size, hashAbierto_name, marker="^", color= "tab:purple", label='HashAbierto_name')
ax1.plot(size, unordered_set_name, marker="s", color= "tab:orange", label='Unordered_set_name')
ax1.plot(size, set_name, marker="P", color='tab:blue', label='Set_name')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper left', shadow=True, fontsize='10')
legend.get_frame().set_facecolor('white')

plt.savefig("Grafico de inserciones user_name.png")
plt.show()

# %% [markdown]
# # Evaluación experimental de busquedas

# %% [markdown]
# ## Valores existentes con clave User_ID

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_id = [0.8983,0.7001,0.80508,0.59914,0.5723337,0.748675,0.5884961] 
hashCerrado_id = [0.2981,0.3999,0.3396,0.31913,0.3121535,0.24992,0.2726807] 
hashAbierto_id = [0.7001,0.40025,0.33932,0.48983,0.5328734,0.4841,0.4650154] 
unordered_set_id = [0.4962,0.44845,0.43934,0.5124,0.3534668,0.504825,0.4570577] 
set_id = [0.4,0.95005,0.77732,0.59017,0.5760001,0.53412,0.5572346] 

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
ax1.plot(size, arbol_id, marker="o", color= "c", label='Arbol_id')
ax1.plot(size, hashCerrado_id, marker="*", color= "y", label='HashCerrado_id')
ax1.plot(size, hashAbierto_id, marker="^", color= "tab:purple", label='HashAbierto_id')
ax1.plot(size, unordered_set_id, marker="s", color= "tab:orange", label='Unordered_set_id')
ax1.plot(size, set_id, marker="P", color='tab:blue', label='Set_id')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper left', shadow=True, fontsize='10')
legend.get_frame().set_facecolor('white')

#fig.tight_layout()  # Para que no se superpongan los labels
plt.savefig("Grafico_valores_existentes_con_USER_ID.png")
plt.show()

# %% [markdown]
# ## Valores No existentes entre el rango de valores con clave User_ID

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_id = [0.5001,0.99805,0.61878,0.61953,0.6324267,0.667925,0.6108732] 
hashCerrado_id = [0.3882,0.14975,0.35944,0.30975,0.2461066,0.25971,0.2842692] 
hashAbierto_id = [0.201,0.30015,0.31962,0.2588,0.3523466,0.419105,0.310673] 
unordered_set_id = [0.6914,0.39935,0.25892,0.41945,0.4665401,0.354585,0.453123] 
set_id = [0.2972,0.77335,0.39886,0.53854,0.4985533,0.531145,0.4764769] 

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
ax1.plot(size, arbol_id, marker="o", color= "c", label='Arbol_id')
ax1.plot(size, hashCerrado_id, marker="*", color= "y", label='HashCerrado_id')
ax1.plot(size, hashAbierto_id, marker="^", color= "tab:purple", label='HashAbierto_id')
ax1.plot(size, unordered_set_id, marker="s", color= "tab:orange", label='Unordered_set_id')
ax1.plot(size, set_id, marker="P", color='tab:blue', label='Set_id')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper left', shadow=True, fontsize='10')
legend.get_frame().set_facecolor('white')

#fig.tight_layout()  # Para que no se superpongan los labels
plt.savefig("Grafico_valores_no_existentes_grandes_con_USER_ID.png")
plt.show()

# %% [markdown]
# ## Valores No existentes cualesquiera (pequeños) con clave User_ID

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_id = [0,0.05,0.12004,0.11996,0.09987324,0.111165,0.10753074] 
hashCerrado_id = [0.399,0.2989,0.18014,0.26883,0.2194533,0.20474,0.19973455] 
hashAbierto_id = [0.4996,0.5501,0.37956,0.26948,0.29642,0.309525,0.3418423] 
unordered_set_id = [0.5967,0.6489,0.37998,0.49974,0.4574,0.499175,0.4687347] 
set_id = [0.3985,0.19935,0.14424,0.24983,0.2864534,0.21661,0.2109346]

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
ax1.plot(size, arbol_id, marker="o", color= "c", label='Arbol_id')
ax1.plot(size, hashCerrado_id, marker="*", color= "y", label='HashCerrado_id')
ax1.plot(size, hashAbierto_id, marker="^", color= "tab:purple", label='HashAbierto_id')
ax1.plot(size, unordered_set_id, marker="s", color= "tab:orange", label='Unordered_set_id')
ax1.plot(size, set_id, marker="P", color='tab:blue', label='Set_id')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper left', shadow=True, fontsize='10')
legend.get_frame().set_facecolor('white')

#fig.tight_layout()  # Para que no se superpongan los labels
plt.savefig("Grafico_valores_no_existentes_pequeños_con_USER_ID.png")
plt.show()

# %% [markdown]
# ## Valores existentes con clave User_Name

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_name = [188.7959,199.2283,190.0529,203.8838,201.7758,192.2009,206.5322] 
hashCerrado_name = [0.6992,0.20135,0.48018,0.50969,0.3956533,0.35439,0.3920232] 
hashAbierto_name = [0.6999,0.75295,0.4393,0.4806,0.5204866,0.57937,0.6169884] 
unordered_set_name = [0.5033,0.59935,0.64,0.60931,0.5168533,0.61515,0.5962462] 
set_name = [0.9992,0.50185,0.93878,0.74002,0.8115473,0.726475,0.7615153] 

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
#ax1.plot(size_exist, arbol_exist_id, marker="o", color= "c", label='Arbol_name')
ax1.plot(size, hashCerrado_name, marker="*", color= "y", label='HashCerrado_name')
ax1.plot(size, hashAbierto_name, marker="^", color= "tab:purple", label='HashAbierto_name')
ax1.plot(size, unordered_set_name, marker="s", color= "tab:orange", label='Unordered_set_name')
ax1.plot(size, set_name, marker="P", color='tab:blue', label='Set_name')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper center', shadow=True, fontsize='12')
legend.get_frame().set_facecolor('white')

ax2 = ax1.twinx()  # Instancia un segundo eje

color = 'tab:orange'
ax2.set_ylabel('Nanosegundos', fontsize='15')#, color=color)  # we already handled the x-label with ax1
ax2.plot(size, arbol_name, marker="o", color= "c", label='Arbol_name')
ax2.tick_params(axis='y') #, labelcolor=color)

legend = plt.legend(loc='upper right', shadow=True, fontsize='12')
legend.get_frame().set_facecolor('white')

fig.tight_layout()  # Para que no se superpongan los labels
plt.savefig("Grafico_valores_existentes_con_USER_NAME.png")
plt.show()

# %% [markdown]
# ## Valores No existentes entre el rango de valores con User_Name

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_name = [195.1189,207.2135,192.0306,204.467,201.773,192.7504,207.9325] 
hashCerrado_name = [0.4971,0.40065,0.35646,0.50904,0.4910534,0.420965,0.4461614] 
hashAbierto_name = [0.4001,0.5497,0.44008,0.56004,0.4548199,0.485375,0.4462769] 
unordered_set_name = [0.4002,0.49925,0.95712,0.51987,0.7168,0.68485,0.5266461] 
set_name = [1.4025,0.69645,0.6187,0.74916,0.97324,0.78638,0.8096575] 

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
#ax1.plot(size_exist, arbol_exist_id, marker="o", color= "c", label='Arbol_name')
ax1.plot(size, hashCerrado_name, marker="*", color= "y", label='HashCerrado_name')
ax1.plot(size, hashAbierto_name, marker="^", color= "tab:purple", label='HashAbierto_name')
ax1.plot(size, unordered_set_name, marker="s", color= "tab:orange", label='Unordered_set_name')
ax1.plot(size, set_name, marker="P", color='tab:blue', label='Set_name')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper center', shadow=True, fontsize='12')
legend.get_frame().set_facecolor('white')

ax2 = ax1.twinx()  # Instancia un segundo eje

color = 'tab:orange'
ax2.set_ylabel('Nanosegundos', fontsize='15')#, color=color)  # we already handled the x-label with ax1
ax2.plot(size, arbol_name, marker="o", color= "c", label='Arbol_name')
#ax2.plot(size_exist, hashCerrado_exist_id, marker="*", color= "y", label='HashCerrado_name')
ax2.tick_params(axis='y') #, labelcolor=color)

legend = plt.legend(loc='upper right', shadow=True, fontsize='12')
legend.get_frame().set_facecolor('white')

fig.tight_layout()  # Para que no se superpongan los labels

plt.savefig("Grafico_valores_no_existentes_grandes_con_USER_NAME.png")
plt.show()

# %% [markdown]
# ## Valores No existentes cualesquiera (pequeños) con User_Name

# %%
# Datos
size = [1000, 2000, 5000, 10000, 15000, 20000, 26000]
arbol_name = [0,0.09845,0.04,0.04982,0.02655999,0.015005,0.03073082] 
hashCerrado_name = [0.1999,0.45075,0.27932,0.3185,0.39905347,0.44443,0.3572346] 
hashAbierto_name = [0.5006,0.44945,0.41938,0.34955,0.6530271,0.405085,0.3911538] 
unordered_set_name = [0.5987,0.89885,0.62024,0.49983,0.5524667,0.56926,0.4227846] 
set_name = [0.1,0.34925,0.33914,0.37918,0.3859799,0.310115,0.3420577]

#plt.figure(figsize=(15,10))

fig, ax1 = plt.subplots(figsize=(10,7))

ax1.set_xlabel('Numero de busquedas promedio', fontsize='15')
ax1.set_ylabel('Nanosegundos', fontsize='15')
ax1.plot(size, arbol_name, marker="o", color= "c", label='Arbol_name')
ax1.plot(size, hashCerrado_name, marker="*", color= "y", label='HashCerrado_name')
ax1.plot(size, hashAbierto_name, marker="^", color= "tab:purple", label='HashAbierto_name')
ax1.plot(size, unordered_set_name, marker="s", color= "tab:orange", label='Unordered_set_name')
ax1.plot(size, set_name, marker="P", color='tab:blue', label='Set_name')
ax1.tick_params(axis='y')#, labelcolor=color)
plt.grid()
legend = plt.legend(loc='upper center', shadow=True, fontsize='11')
legend.get_frame().set_facecolor('white')

#fig.tight_layout()  # Para que no se superpongan los labels
plt.savefig("Grafico_valores_no_existentes_pequeños_con_USER_NAME.png")
plt.show()
